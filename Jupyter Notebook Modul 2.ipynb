# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tatiana Yunina**\
# Graphic designer at the moment

# %% [markdown]
# *I am interested in data science because I want to learn more about machine learning and work in this field*

# %% [markdown]
# ### Multiplication

# %%
a = 5
b = 7
print(a*b)
# Out:
# 35

# %% [markdown]
# 1. one
# 2. two
# 3. three
# 4. four
# 5. five
#
# ~~There was supposed to be a table here, but I didn't want to~~
#
# |*Left-Aligned*| **Center Aligned** | ***Right Aligned*** |
# |:-------------|:--------------:| -------------:|
#
# ![](//encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3pJ8NlmcSDu9jDwJY7rrpE_1xOHkxPI13aw&usqp=CAU/150x100)
